# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/autos_random_50k_cleaned.csv")
df.head()
# Out:
#    Unnamed: 0      date_crawled  \
# 0           1  2016-04-02 14:51
# 1           2  2016-03-19 18:36
# 2           3  2016-03-09 20:59
# 3           4  2016-03-26 15:55
# 4           5  2016-03-29 14:47
#
#                                           car_name  price_EUR ab_test  \
# 0                      Astra_G_Cabrio_Turbo_235_PS       5200    test
# 1  Fiat_Grande_Punto_1.2_8V__MIT_2_JAHREN_GARANTIE       3400    test
# 2                           Volvo_XC60_D5_AWD_Aut.       5200    test
# 3                  Kombi_Technisch_super_in_Schuss        750    test
# 4              Audi_A4_1.9_TDI_quattro_Delphingrau       3522    test
#
#   vehicle_type  registration_year transmission  power_ps     model  \
# 0       cabrio               2002      manuell       235     astra
# 1   kleinwagen               2006      manuell        65    andere
# 2          suv               2009    automatik       220  xc_reihe
# 3        kombi               2000      manuell       112    mondeo
# ...

# %%
df.tail()
# Out:
#        Unnamed: 0      date_crawled  \
# 37861       49994  2016-03-13 12:41
# 37862       49995   2016-03-10 0:59
# 37863       49996  2016-03-06 17:46
# 37864       49997   2016-03-09 0:56
# 37865       49998   2016-03-13 8:47
#
#                                          car_name  price_EUR  ab_test  \
# 37861          Mercedes_Benz_Vaneo_CDI_1.7_Family       3000     test
# 37862                    Toyota_RAV_4_2.2D_110_kw       6590  control
# 37863                          Mercedes_190e_W201       1250  control
# 37864         Peugeot_Boxer_HDi_335_L2H2_verglast      12500     test
# 37865  FIAT_PUNTO_1.2___16V__SPORTING___TÜV_neu__        999  control
#
#       vehicle_type  registration_year transmission  power_ps     model  \
# 37861          bus               2002      manuell        91    andere
# 37862          suv               2010      manuell       150       rav
# 37863    limousine               1991      manuell       120  c_klasse
# ...

# %%
df.shape
# Out:
# (37866, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37866 entries, 0 to 37865
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          37866 non-null  int64
#  1   date_crawled        37866 non-null  object
#  2   car_name            37866 non-null  object
#  3   price_EUR           37866 non-null  int64
#  4   ab_test             37866 non-null  object
#  5   vehicle_type        37866 non-null  object
#  6   registration_year   37866 non-null  int64
#  7   transmission        37866 non-null  object
#  8   power_ps            37866 non-null  int64
#  9   model               37866 non-null  object
#  10  odometer_km         37866 non-null  int64
#  11  registration_month  37866 non-null  int64
#  12  fuel_type           37866 non-null  object
#  13  brand               37866 non-null  object
#  14  unrepaired_damage   37866 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'date_crawled', 'car_name', 'price_EUR', 'ab_test',
#        'vehicle_type', 'registration_year', 'transmission', 'power_ps',
#        'model', 'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'postal_code', 'last_seen'],
#       dtype='object')

# %%
df["ab_test"].unique()
# Out:
# array(['test', 'control'], dtype=object)

# %%
df.describe()
# Out:
#          Unnamed: 0      price_EUR  registration_year      power_ps  \
# count  37866.000000   37866.000000       37866.000000  37866.000000
# mean   25020.837215    6838.213595        2003.529314    129.625363
# std    14457.964236   11615.915258           6.725368     64.633507
# min        1.000000     500.000000        1929.000000      1.000000
# 25%    12499.500000    1700.000000        2000.000000     86.000000
# 50%    25026.000000    3950.000000        2004.000000    116.000000
# 75%    37601.250000    8500.000000        2008.000000    156.000000
# max    49998.000000  820000.000000        2016.000000   1403.000000
#
#          odometer_km  registration_month   postal_code
# count   37866.000000        37866.000000  37866.000000
# mean   124270.717794            6.396820  51743.524613
# std     39764.869422            3.338199  25656.493782
# min      5000.000000            1.000000   1067.000000
# 25%    100000.000000            4.000000  31368.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace= True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# Unnamed: 0            37866
# date_crawled          11420
# car_name              28377
# price_EUR              2121
# ab_test                   2
# vehicle_type              9
# registration_year        74
# transmission              3
# power_ps                395
# model                   244
# odometer_km              13
# registration_month       12
# fuel_type                 8
# brand                    40
# unrepaired_damage         3
# ad_created               63
# postal_code            6641
# last_seen              8941
# dtype: int64

# %%
df['model'].value_counts()
# Out:
# golf       3117
# andere     2718
# 3er        2260
# Unknown    1189
# polo       1172
#            ...
# lodgy         2
# i3            1
# move          1
# kappa         1
# materia       1
# Name: model, Length: 244, dtype: int64

# %%
df.car_name.value_counts()
# Out:
# BMW_318i                                                     92
# Volkswagen_Golf_1.4                                          90
# BMW_320i                                                     71
# BMW_316i                                                     61
# Volkswagen_Polo                                              61
#                                                              ..
# Tausche_opel                                                  1
# Vw_polo_1_2_12v_klima                                         1
# Opel_Corsa_C_1.0_NJoy                                         1
# Volkswagen_Passat_1.4_TSI_BlueMotion_Technology_Trendline     1
# FIAT_PUNTO_1.2___16V__SPORTING___TÜV_neu__                    1
# Name: car_name, Length: 28377, dtype: int64

# %%
df.vehicle_type.value_counts()
# Out:
# limousine     11046
# kleinwagen     7977
# kombi          7615
# bus            3499
# cabrio         2711
# coupe          2140
# suv            1762
# Unknown         819
# andere          297
# Name: vehicle_type, dtype: int64

# %%
df.odometer_km.value_counts()
# Out:
# 150000    23513
# 125000     4161
# 100000     1719
# 90000      1435
# 80000      1229
# 70000      1170
# 60000      1031
# 50000       895
# 40000       799
# 30000       729
# 20000       661
# 5000        322
# 10000       202
# Name: odometer_km, dtype: int64

# %%
df['postal_code']=df['postal_code'].astype('object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37866 entries, 0 to 37865
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          37866 non-null  int64
#  1   date_crawled        37866 non-null  object
#  2   car_name            37866 non-null  object
#  3   price_EUR           37866 non-null  int64
#  4   ab_test             37866 non-null  object
#  5   vehicle_type        37866 non-null  object
#  6   registration_year   37866 non-null  int64
#  7   transmission        37866 non-null  object
#  8   power_ps            37866 non-null  int64
#  9   model               37866 non-null  object
#  10  odometer_km         37866 non-null  int64
#  11  registration_month  37866 non-null  int64
#  12  fuel_type           37866 non-null  object
#  13  brand               37866 non-null  object
#  14  unrepaired_damage   37866 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# date_crawled          0
# car_name              0
# price_EUR             0
# ab_test               0
# vehicle_type          0
# registration_year     0
# transmission          0
# power_ps              0
# model                 0
# odometer_km           0
# registration_month    0
# fuel_type             0
# brand                 0
# unrepaired_damage     0
# ad_created            0
# postal_code           0
# last_seen             0
# dtype: int64

# %%
df["ab_test"].fillna("No car",inplace = True)
df.head()
# Out:
#    Unnamed: 0      date_crawled  \
# 0           1  2016-04-02 14:51
# 1           2  2016-03-19 18:36
# 2           3  2016-03-09 20:59
# 3           4  2016-03-26 15:55
# 4           5  2016-03-29 14:47
#
#                                           car_name  price_EUR ab_test  \
# 0                      Astra_G_Cabrio_Turbo_235_PS       5200    test
# 1  Fiat_Grande_Punto_1.2_8V__MIT_2_JAHREN_GARANTIE       3400    test
# 2                           Volvo_XC60_D5_AWD_Aut.       5200    test
# 3                  Kombi_Technisch_super_in_Schuss        750    test
# 4              Audi_A4_1.9_TDI_quattro_Delphingrau       3522    test
#
#   vehicle_type  registration_year transmission  power_ps     model  \
# 0       cabrio               2002      manuell       235     astra
# 1   kleinwagen               2006      manuell        65    andere
# 2          suv               2009    automatik       220  xc_reihe
# 3        kombi               2000      manuell       112    mondeo
# ...

# %%
mean=int(df["odometer_km"].mean())
df["odometer_km"].fillna(mean,inplace=True)
df.head()
# Out:
#    Unnamed: 0      date_crawled  \
# 0           1  2016-04-02 14:51
# 1           2  2016-03-19 18:36
# 2           3  2016-03-09 20:59
# 3           4  2016-03-26 15:55
# 4           5  2016-03-29 14:47
#
#                                           car_name  price_EUR ab_test  \
# 0                      Astra_G_Cabrio_Turbo_235_PS       5200    test
# 1  Fiat_Grande_Punto_1.2_8V__MIT_2_JAHREN_GARANTIE       3400    test
# 2                           Volvo_XC60_D5_AWD_Aut.       5200    test
# 3                  Kombi_Technisch_super_in_Schuss        750    test
# 4              Audi_A4_1.9_TDI_quattro_Delphingrau       3522    test
#
#   vehicle_type  registration_year transmission  power_ps     model  \
# 0       cabrio               2002      manuell       235     astra
# 1   kleinwagen               2006      manuell        65    andere
# 2          suv               2009    automatik       220  xc_reihe
# 3        kombi               2000      manuell       112    mondeo
# ...

# %%
df.index[df["price_EUR"] >= 800000].tolist()
# Out:
# [7501]

# %%
df.loc[7501]
# Out:
# Unnamed: 0                                                         9908
# date_crawled                                           2016-03-31 19:55
# car_name              McLaren_675LT_Spider/Delivery_on1._May/Vat_is_...
# price_EUR                                                        820000
# ab_test                                                         control
# vehicle_type                                                     cabrio
# registration_year                                                  2016
# transmission                                                    Unknown
# power_ps                                                            674
# model                                                           Unknown
# odometer_km                                                        5000
# registration_month                                                    3
# fuel_type                                                        benzin
# ...

# %%
df["price_EUR"].median()
# Out:
# 3950.0

# %%
value=df["price_EUR"].median()
df["price_EUR"][7501]=value
# Out:
# <ipython-input-32-fae4d3a582b2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["price_EUR"][7501]=value

# %%
df.loc[7501]
# Out:
# Unnamed: 0                                                         9908
# date_crawled                                           2016-03-31 19:55
# car_name              McLaren_675LT_Spider/Delivery_on1._May/Vat_is_...
# price_EUR                                                          3950
# ab_test                                                         control
# vehicle_type                                                     cabrio
# registration_year                                                  2016
# transmission                                                    Unknown
# power_ps                                                            674
# model                                                           Unknown
# odometer_km                                                        5000
# registration_month                                                    3
# fuel_type                                                        benzin
# ...

# %%
plt.hist(df["price_EUR"])
# Out:
# (array([3.7759e+04, 8.5000e+01, 1.1000e+01, 3.0000e+00, 3.0000e+00,
#         1.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00, 3.0000e+00]),
#  array([5.0000e+02, 6.2350e+04, 1.2420e+05, 1.8605e+05, 2.4790e+05,
#         3.0975e+05, 3.7160e+05, 4.3345e+05, 4.9530e+05, 5.5715e+05,
#         6.1900e+05]),
#  <a list of 10 Patch objects>)

# %%
sns.boxplot(df["price_EUR"])
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
corr = df.corr()
sns.heatmap(
    corr, xticklabels=corr.columns , yticklabels=corr.columns, annot= True,
          cmap=sns.diverging_palette(220,20, as_cmap= True)
)

# %%
fig,ax=plt.subplots(figsize=(20,20))
plt_1 = plt.figure(figsize=(3, 6))
ax.scatter(df["price_EUR"],df["registration_year"])
ax.set_xlabel("price")
ax.set_ylabel("per year")
plt.show()

# %%
df.plot(subplots= True , figsize=(20,20));

# %%
sns.pairplot(df,hue='fuel_type')

# %%
plt.figure(figsize=(15,8))
sns.countplot(x=df['vehicle_type'])

# %%
plt.figure(figsize=(15,25))
df['vehicle_type'].value_counts().plot.pie(autopct='1.1 %f%%')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(20,20))
ax.scatter(df['price_EUR'],df['power_ps'])
ax.set_xlabel('PRICE')
ax.set_ylabel('POWER OF CAR')
plt.show()

# %%
sns.lineplot(x='registration_year',y='registration_month',label='increases',data=df)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(40,30))
plt.title('brand with price of cars')
sns.barplot(x='brand',y='price_EUR',data=df,hue='fuel_type',order=df['brand'].value_counts().index,palette='rocket')
plt.xlabel('brand',fontsize=15)
plt.show()

# %%
Conclusion :
My Topic Name is Auto random car sales .In this dataset we are finding the Null value which are present in columns 
. After find the null value from there data cleaning process start . 
In in dataset we are checking that, how many sellling car in this month and total registration.And we have check that how many cars 
was most coslty with the year. And one more thing that how much Euro price of registraction according the year.
Here In line plot we are mention that registration_year and registration_month , mean that How many registration are increases according to year with the 
help of months.
In a barplot we have sho that the brand car with the price and the car are belong in which category like fuel , gas these things.
There are many lots of vehical types like on this year which car are launched these things are represent the pieplot .
